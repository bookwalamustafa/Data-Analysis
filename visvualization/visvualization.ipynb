# %% [markdown]
# # INFO 212: Data Science Programming 1
# ## CCI at Drexel University
#
#
# ## Lab: Visualization

# %% [markdown]
# ## What to do:
# - Answer each question individually.
# - Comment on each single statement.
# - Each missing comment will be penalized by 1 point.
# - Verify the code by showing meaningful results.

# %%
# Importing necessary libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exercise
# The Iris flower data set consists of 50 samples from each of three species of Iris Flowers — Iris Setosa, Iris Virginica and Iris Versicolor:
#
# ![](https://i.imgur.com/jb6jvPy.png)
#
# Each flower is described by 4 features: sepal length, sepal width, petal length and petal width, in centimeters.

# %% [markdown]
# 1. Load the iris.csv data into a DataFrame. Show the shape of the dataset. List the columns and their datatypes. Compute summary statistics. Show the first 5 rows of the data.

# %%
df = pd.read_csv("/Users/mustafabookwala/Desktop/Drexel/Pre-Junior/Fall 2024/INFO 212/Week 5/iris.csv")  # Loading the dataset as a dataframe

# Printing the results
print(f"Shape of the dataframe: {df.shape}\n")
print(f"Columns of the dataframe: {df.columns}\n")
print(f"Data types of the columns: {df.dtypes}\n")
print(f"Summary statistics: \n{df.describe()}\n")
print(f"First 5 rows: \n{df.head()}")
# Out:
# Shape of the dataframe: (150, 5)
#
# Columns of the dataframe: Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#
# Data types of the columns: sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
#
# Summary statistics:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
#
# First 5 rows:
# ...

# %% [markdown]
# 2. List the unique names of the species. Show the distribution of species.

# %%
print(df['species'].value_counts())  # Printing the count of all the unique species
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# 3.  Use seaborn.histplot() to plot histograms for each of the feature columns, colored by the species. You should have 4 histogram plots. What do you see from the plots? Explain the distributions against the species.

# %%
columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']  # List of all the columns in the dataframe

for column in columns:  # Loop for each column in the above list
    plt.figure(figsize=(8, 5))  # Sets the size of the histogram
    sns.histplot(data=df, x=column, hue='species')  # Uses seaborn for the histogram. Sets the x-axis as the respective column and hue acts as the different color for each species
    plt.title(f'Histogram for {column} by species')  # Sets the title of the histogram
    plt.show()  # Displays the histogram

# %% [markdown]
# # Observation for Question 3 -
#
# **Graph 1**:
# * Setosa has a shorter sepal length, clustered between 4.5 and 5.5cm
# * Versicolor has sepal lenghts centered around 5.5 and 6.5cm
# * Virginica has the longest sepal length mostly between 6 and 7.5cm
#
# **Graph 2**:
# * Setosa has a higher sepal width, between 3 and 4cm
# * Versicolor has sepal widths predominantly around 2.5 and 3cm, which shows an intermediate range.
# * Virginica has a similar range to Versicolor but slight overlaps with Setosa at 3cm
#
# **Graph 3:**
# * Setosa has very short petal lengths around 1cm
# * Versicolor has petal lengths in the range of around 3 to 5cm
# * Virginica has the longest petal lengths, ranging from 4.5 to 6.5cm
#
# **Graph 4:**
# * Setosa has the narrowest petal widths, mostly around 0.2cm
# * Versicolor has petal widths around 1 and 1.5cm
# * Virginica has the widths petal widths, around 1.5 to 2.5cm

# %% [markdown]
# 4. Scatter plot all pairs of different features and color the points with the species. You should have 6 scatter plots.

# %%
columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']  # List of all the columns in the dataframe

for i in range(len(columns)):  # Loops from 0 to the end of the above list
    for j in range(i + 1, len(columns)):  # Loops from the consecutive element till the end of the list
        plt.figure(figsize=(8, 5))  # Sets the size of the scatter plot
        sns.scatterplot(data=df, x=columns[i], y=columns[j], hue='species')  # Uses seaborn for the scatterplot. Sets the x-axis and y-axis as the respective columns and hue acts as the different color for each species
        plt.title(f'Scatter Plot for {columns[i]} vs {columns[j]}')  # Sets the title of the scatterplot
        plt.show()  # Displays the scatterplot

# %% [markdown]
# 5. Based on the plots in above question (4), write a brief discussion of your findings about the features and species. For example, which features are indicative to separate the species, etc.

# %% [markdown]
# # Observation for Question 4 -
#
# **Graph 1**:
# * Setosa has a higher sepal width and shorter sepal length, clustering around 3-4cm in width and 4-5.5cm in length.
# * Versicolor and Virginica overlap significantly, with sepal lengths around 5-7cm and widths mostly between 2.5-3.5cm.
#
# **Graph 2**:
# * Setosa has a distinct cluster at lower petal lengths, around 1-1.5cm.
# * Versicolor’s petal length centers around 3-5cm, while Virginica tends to be longer, between 4.5 and 6.5cm.
#
# **Graph 3**:
# * Setosa has the smallest petal widths, around 0.2-0.5cm.
# * Versicolor and Virginica overlap but show a trend, with Virginica generally having larger petal widths, around 1-2cm.
#
# **Graph 4**:
# * Setosa forms a clear cluster with lower petal lengths (around 1-1.5cm) and slightly higher sepal widths (3-4cm).
# * Virginica generally has larger petal lengths (4-6cm), while Versicolor falls in between, creating a gradient.
#
# **Graph 5**:
# * Setosa has consistently lower petal widths, around 0.2-0.5cm.
# * Versicolor and Virginica overlap, but Virginica typically has larger petal widths, around 1.5-2cm.
#
# **Graph 6**:
# * Setosa stands out with both low petal length (around 1cm) and width (0.2-0.5cm).
# * Versicolor and Virginica are distinguishable, with Virginica showing larger values in both petal length (4-6cm) and width (1.5-2.5cm).
#
# The graphs of petal_width v/s petal_length, petal_length v/s sepal_length are the plots with which we can easily distinguish between the species because they are very well spread out.
